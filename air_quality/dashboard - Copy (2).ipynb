# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama:Rizki Dwi Novita
# - Email:rizkidwinovita2@gmail.com
# - Id Dicoding:

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - pertanyaan 1.
#  Bagaimana perubahan kualitas udara dari tahun ke tahun (2013-2017)?
# - pertanyaan 2.
# Apakah ada perbedaan signifikan kualitas udara antar stasiun?
# - pertanyaan 3.
# Bagaimana faktor-faktor seperti suhu (TEMP) dan tekanan udara (PRES) berpengaruh terhadap kualitas udara?

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
"""air_quality = ['PRSA_Data_Aotizhongxin_20130301-20170228.csv', 'PRSA_Data_Changping_20130301-20170228.csv', 'PRSA_Data_Dingling_20130301-20170228.csv', 'PRSA_Data_Dongsi_20130301-20170228.csv', 'PRSA_Data_Guanyuan_20130301-20170228.csv', 'PRSA_Data_Gucheng_20130301-20170228.csv', 'PRSA_Data_Huairou_20130301-20170228.csv', 'PRSA_Data_Nongzhanguan_20130301-20170228.csv', 'PRSA_Data_Shunyi_20130301-20170228.csv', 'PRSA_Data_Tiantan_20130301-20170228.csv', 'PRSA_Data_Wanliu_20130301-20170228.csv', 'PRSA_Data_Wanshouxigong_20130301-20170228.csv']

data_frames = []

for csv_file in air_quality:
    file_path = f'D:/2. Coding dll/3. Dicoding/5. Data Science/dashboard/air_quality/{csv_file}'
    combined_df = pd.read_csv(file_path)
    data_frames.append(combined_df)

combined_df = pd.concat(data_frames, ignore_index=True)

print(combined_df.head())"""

air_quality = ['PRSA_Data_Aotizhongxin_20130301-20170228.csv', 'PRSA_Data_Changping_20130301-20170228.csv', 'PRSA_Data_Dingling_20130301-20170228.csv', 'PRSA_Data_Dongsi_20130301-20170228.csv', 'PRSA_Data_Guanyuan_20130301-20170228.csv', 'PRSA_Data_Gucheng_20130301-20170228.csv', 'PRSA_Data_Huairou_20130301-20170228.csv', 'PRSA_Data_Nongzhanguan_20130301-20170228.csv', 'PRSA_Data_Shunyi_20130301-20170228.csv', 'PRSA_Data_Tiantan_20130301-20170228.csv', 'PRSA_Data_Wanliu_20130301-20170228.csv', 'PRSA_Data_Wanshouxigong_20130301-20170228.csv']

data_frames = []

for csv_file in air_quality:
    file_path = f'D:/2. Coding dll/3. Dicoding/5. Data Science/dashboard/air_quality/{csv_file}'
    df = pd.read_csv(file_path)
    data_frames.append(df)

combined_df = pd.concat(data_frames, ignore_index=True)

print(combined_df.head())
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai tabel `combined_df`

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %%
###missing_values = combined_df.isna().sum()
###print(missing_values)
combined_df.isna().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
print("Jumlah duplikasi: ", combined_df.duplicated().sum())
combined_df.describe()
# Out:
# Jumlah duplikasi:  0
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  412029.000000  414319.000000  411747.000000
# mean       11.500000      79.793428     104.602618      15.830835
# std         6.922195      80.822391      91.772426      21.650603
# min         0.000000       2.000000       2.000000       0.285600
# 25%         5.750000      20.000000      36.000000       3.000000
# 50%        11.500000      55.000000      82.000000       7.000000
# 75%        17.250000     111.000000     145.000000      20.000000
# max        23.000000     999.000000     999.000000     500.000000
#
#                  NO2             CO             O3           TEMP  \
# count  408652.000000  400067.000000  407491.000000  420370.000000
# mean       50.638586    1230.766454      57.372271      13.538976
# std        35.127912    1160.182716      56.661607      11.436139
# min         1.026500     100.000000       0.214200     -19.900000
# 25%        23.000000     500.000000      11.000000       3.100000
# 50%        43.000000     900.000000      45.000000      14.500000
# 75%        71.000000    1500.000000      82.000000      23.300000
# max       290.000000   10000.000000    1071.000000      41.600000
#
#                 PRES           DEWP           RAIN           WSPM
# count  420375.000000  420365.000000  420378.000000  420450.000000
# mean     1010.746982       2.490822       0.064476       1.729711
# std        10.474055      13.793847       0.821004       1.246386
# min       982.400000     -43.400000       0.000000       0.000000
# 25%      1002.300000      -8.900000       0.000000       0.900000
# 50%      1010.400000       3.100000       0.000000       1.400000
# 75%      1019.000000      15.100000       0.000000       2.200000
# max      1042.800000      29.100000      72.500000      13.200000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan tabel `combined_df`

# %% [markdown]
# ##### Missing values

# %%
missing_values = combined_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].isna()
missing_data = combined_df[missing_values]

missing_values_sum = missing_values.sum()
print(missing_values_sum)
# Out:
# PM2.5     8739
# PM10      6449
# SO2       9021
# NO2      12116
# CO       20701
# O3       13277
# TEMP       398
# PRES       393
# DEWP       403
# RAIN       390
# wd        1822
# WSPM       318
# dtype: int64

# %%
for column in combined_df.columns[5:18]:  # Memilih kolom 'PM2.5' hingga 'WSPM'
    print(f"Value counts for {column}:\n{combined_df[column].value_counts()}\n")
# Out:
# Value counts for PM2.5:
# PM2.5
# 3.0      8810
# 10.0     7088
# 9.0      6886
# 8.0      6836
# 11.0     6831
#          ...
# 70.7        1
# 123.7       1
# 48.8        1
# 114.6       1
# 823.0       1
# Name: count, Length: 888, dtype: int64
#
# Value counts for PM10:
# PM10
# 6.0      4945
# 18.0     3748
# 5.0      3731
# 14.0     3725
# 16.0     3616
#          ...
# 15.9        1
# 40.3        1
# 315.1       1
# 134.1       1
# 950.0       1
# Name: count, Length: 1084, dtype: int64
#
# Value counts for SO2:
# SO2
# 2.0000      98557
# 3.0000      32784
# 4.0000      21716
# 5.0000      17964
# 6.0000      16567
#             ...
# 274.0000        1
# 238.0000        1
# 293.0000        1
# 83.1096         1
# 236.0000        1
# Name: count, Length: 691, dtype: int64
#
# Value counts for NO2:
# NO2
# 16.0     5799
# 22.0     5755
# 20.0     5718
# 17.0     5690
# 18.0     5676
#          ...
# 50.6        1
# 34.8        1
# 21.7        1
# 27.7        1
# 112.8       1
# Name: count, Length: 1212, dtype: int64
#
# Value counts for CO:
# CO
# 300.0     32308
# 400.0     31275
# 500.0     29171
# 600.0     28035
# 700.0     26488
#           ...
# 350.0         1
# 8199.0        1
# 8099.0        1
# 7099.0        1
# 8599.0        1
# Name: count, Length: 132, dtype: int64
#
# Value counts for O3:
# O3
# 2.0      42327
# 3.0       8720
# 4.0       8049
# 1.0       6958
# 5.0       6462
#          ...
# 106.7        1
# 5.1          1
# 54.6         1
# 30.7         1
# 5.3          1
# Name: count, Length: 1598, dtype: int64
#
# Value counts for TEMP:
# TEMP
#  3.000000     3414
#  1.000000     2903
#  0.000000     2739
#  2.000000     2687
# -1.000000     2562
#               ...
#  8.533333        1
#  14.675000       1
#  14.050000       1
#  14.775000       1
# -0.666667        1
# Name: count, Length: 2034, dtype: int64
#
# Value counts for PRES:
# PRES
# 1019.000000    2948
# 1021.000000    2932
# 1018.000000    2868
# 1020.000000    2862
# 1023.000000    2838
#                ...
# 1020.857143       1
# 1021.666667       1
# 1019.133333       1
# 1013.333333       1
# 1025.033333       1
# Name: count, Length: 726, dtype: int64
#
# Value counts for DEWP:
# DEWP
#  17.6    1559
#  17.0    1519
#  17.2    1490
#  16.8    1483
#  17.3    1455
#          ...
# -35.7       1
# -43.4       1
# -36.0       1
#  29.0       1
# -33.3       1
# Name: count, Length: 645, dtype: int64
#
# Value counts for RAIN:
# RAIN
# 0.0     403858
# 0.1       3722
# 0.2       1841
# 0.3       1382
# 0.4        907
#          ...
# 36.1         1
# 18.2         1
# 26.7         1
# 18.9         1
# 22.4         1
# Name: count, Length: 253, dtype: int64
#
# Value counts for wd:
# wd
# NE     43335
# ENE    34142
# NW     32600
# N      30869
# E      29752
# SW     28756
# NNE    28232
# NNW    25326
# WNW    24375
# ESE    24220
# SSW    22563
# SE     20074
# WSW    20040
# S      19405
# SSE    17694
# W      17563
# Name: count, dtype: int64
#
# Value counts for WSPM:
# WSPM
# 1.1     22249
# 1.0     22150
# 1.2     22141
# 0.9     20955
# 1.3     20383
#         ...
# 11.8        1
# 11.7        1
# 10.4        1
# 12.8        1
# 13.2        1
# Name: count, Length: 117, dtype: int64
#
# Value counts for station:
# station
# Aotizhongxin     35064
# Changping        35064
# Dingling         35064
# Dongsi           35064
# Guanyuan         35064
# Gucheng          35064
# Huairou          35064
# Nongzhanguan     35064
# Shunyi           35064
# Tiantan          35064
# Wanliu           35064
# Wanshouxigong    35064
# Name: count, dtype: int64

# %%
for column in combined_df.columns[5:18]:
    if combined_df[column].dtype == 'float64':  # Periksa apakah tipe data kolom adalah numerik
        combined_df[column].fillna(combined_df[column].mean(), inplace=True)
    else:
        print(f"Skipped filling missing values for non-numeric column: {column}")
# Out:
# Skipped filling missing values for non-numeric column: wd
# Skipped filling missing values for non-numeric column: station

# %%
# Pengisian nilai rata-rata untuk kolom numerik
numeric_columns = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']
for column in numeric_columns:
    combined_df[column].fillna(combined_df[column].mean(), inplace=True)

# Pengisian nilai modus untuk kolom kategori 'wd'
combined_df['wd'].fillna(combined_df['wd'].mode()[0], inplace=True)

# %%
###missing_values = combined_df.isna().sum()
###print(missing_values)
combined_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
# Contoh dataframe
data = {'year': [2013, 2014, 2015, 2016, 2017, 2013.5, 2014.5],
        'PM2.5': [20, 25, 18, 22, 30, 21, 27],
        'PM10': [40, 45, 38, 42, 50, 41, 47]}

df = pd.DataFrame(data)

# Cek nilai unik dalam kolom 'year'
unique_values = df['year'].unique()

# Jika terdapat nilai desimal, tampilkan pesan peringatan
if any(val % 1 != 0 for val in unique_values):
    print("Peringatan: Kolom 'year' mengandung nilai desimal.")

# Konversi kolom 'year' ke tipe data integer
df['year'] = df['year'].astype(int)

# Tampilkan hasil
print(df)
# Out:
# Peringatan: Kolom 'year' mengandung nilai desimal.
#    year  PM2.5  PM10
# 0  2013     20    40
# 1  2014     25    45
# 2  2015     18    38
# 3  2016     22    42
# 4  2017     30    50
# 5  2013     21    41
# 6  2014     27    47

# %% [markdown]
# ###mengubah tipe data kolom ‘year’ menjadi integer.

# %%
pm_data.loc[:, 'year'] = pm_data['year'].astype(int)
print(pm_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\2. Coding dll\3. Dicoding\5. Data Science\dashboard\air_quality\dashboard.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/2.%20Coding%20dll/3.%20Dicoding/5.%20Data%20Science/dashboard/air_quality/dashboard.ipynb#Y150sZmlsZQ%3D%3D?line=0'>1</a> pm_data.loc[:, 'year'] = pm_data['year'].astype(int)
#       <a href='vscode-notebook-cell:/d%3A/2.%20Coding%20dll/3.%20Dicoding/5.%20Data%20Science/dashboard/air_quality/dashboard.ipynb#Y150sZmlsZQ%3D%3D?line=1'>2</a> print(pm_data)
#
# NameError: name 'pm_data' is not defined

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore `combined_df`

# %%
combined_df.sample(5)
# Out:
#            No  year  month  day  hour       PM2.5        PM10        SO2  \
# 142756   2501  2013      6   13     4  104.000000   90.000000  26.000000
# 143765   3510  2013      7   25     5   79.793428  104.602618  15.830835
# 338449  22874  2015     10   10     1    9.000000    9.000000   3.000000
# 309290  28779  2016      6   12     2   81.000000   81.000000  15.830835
# 182860   7541  2014      1    9     4   16.000000   24.000000  10.000000
#
#               NO2           CO         O3  TEMP    PRES  DEWP  RAIN   wd  \
# 142756  53.000000   400.000000  36.000000  17.2  1003.1  15.5   0.0    N
# 143765  50.638586  1230.766454  57.372271  23.1   996.4  19.3   0.0  ENE
# 338449  16.000000   300.000000  39.000000  10.6  1011.0  -5.4   0.0    N
# 309290   2.000000  1230.766454   2.000000  21.3  1005.6  15.6   0.0  ENE
# 182860  10.000000   700.000000  66.000000  -4.3  1025.1 -25.1   0.0    W
#
#         WSPM   station
# 142756   0.5  Guanyuan
# 143765   1.1  Guanyuan
# 338449   2.4   Tiantan
# 309290   2.4    Shunyi
# 182860   1.9   Gucheng

# %%
combined_df.describe(include="all")
# Out:
#                    No           year          month            day  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17532.500000    2014.662560       6.522930      15.729637
# std      10122.116943       1.177198       3.448707       8.800102
# min          1.000000    2013.000000       1.000000       1.000000
# 25%       8766.750000    2014.000000       4.000000       8.000000
# 50%      17532.500000    2015.000000       7.000000      16.000000
# 75%      26298.250000    2016.000000      10.000000      23.000000
# max      35064.000000    2017.000000      12.000000      31.000000
#
#                  hour          PM2.5           PM10            SO2  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        11.500000      79.793428     104.602618      15.830835
# std          6.922195      79.978679      91.066422      21.417257
# min          0.000000       2.000000       2.000000       0.285600
# 25%          5.750000      21.000000      36.000000       3.000000
# 50%         11.500000      57.000000      84.000000       8.000000
# 75%         17.250000     109.000000     144.000000      19.000000
# max         23.000000     999.000000     999.000000     500.000000
#
#                   NO2             CO             O3           TEMP  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        50.638586    1230.766454      57.372271      13.538976
# std         34.618463    1131.283304      55.760484      11.430729
# min          1.026500     100.000000       0.214200     -19.900000
# 25%         24.000000     500.000000      12.000000       3.100000
# 50%         45.000000     900.000000      47.000000      14.500000
# 75%         70.000000    1500.000000      80.000000      23.200000
# max        290.000000   10000.000000    1071.000000      41.600000
#
#                  PRES           DEWP           RAIN      wd           WSPM  \
# count   420768.000000  420768.000000  420768.000000  420768  420768.000000
# unique            NaN            NaN            NaN      16            NaN
# top               NaN            NaN            NaN      NE            NaN
# freq              NaN            NaN            NaN   45157            NaN
# mean      1010.746982       2.490822       0.064476     NaN       1.729711
# std         10.469162      13.787240       0.820624     NaN       1.245914
# min        982.400000     -43.400000       0.000000     NaN       0.000000
# 25%       1002.300000      -8.900000       0.000000     NaN       0.900000
# 50%       1010.400000       3.000000       0.000000     NaN       1.400000
# 75%       1019.000000      15.100000       0.000000     NaN       2.200000
# max       1042.800000      29.100000      72.500000     NaN      13.200000
#
#              station
# count         420768
# unique            12
# top     Aotizhongxin
# freq           35064
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
# Pilih kolom 'year' dan 'CO' untuk analisis
co2_data = combined_df[['year', 'CO']]

# Kelompokkan data berdasarkan tahun dan hitung rata-rata CO untuk setiap tahun
average_co_by_year = co2_data.groupby('year')['CO'].mean().reset_index()

# Tampilkan DataFrame hasil
print(average_co_by_year)
# Out:
#    year           CO
# 0  2013  1207.158290
# 1  2014  1256.055700
# 2  2015  1257.385873
# 3  2016  1140.803148
# 4  2017  1590.156382

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
import matplotlib.pyplot as plt

# Plot rata-rata CO per tahun
plt.figure(figsize=(10, 6))
plt.plot(average_co_by_year['year'], average_co_by_year['CO'], marker='o', linestyle='-', color='b')
plt.title('Rata-Rata Konsentrasi CO Tahunan (2013-2017)')
plt.xlabel('Tahun')
plt.ylabel('Rata-Rata Konsentrasi CO')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
sns.barplot(x='station', y='Rata-rata', hue='Polusi', data=sorted_stations, palette='viridis')
plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('Stasiun')
plt.ylabel('Rata-rata Tingkat Polusi')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='station', y='Rata-rata', hue='Polusi', data=sorted_stations, palette='viridis')

# Menambahkan label pada setiap batang
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 10), 
                   textcoords = 'offset points')

plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('Stasiun')
plt.ylabel('')  # Menghapus label sumbu y
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='station', y='Rata-rata', hue='Polusi', data=sorted_stations, palette='viridis')

# Menambahkan label pada setiap batang
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 10), 
                   textcoords = 'offset points')

plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('Stasiun')
plt.ylabel('')  # Menghapus label sumbu y
plt.yticks([])  # Menghapus nilai-nilai pada sumbu y
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='station', y='Rata-rata', hue='Polusi', data=sorted_stations, palette='viridis')

# Menambahkan label pada setiap batang
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 10), 
                   textcoords = 'offset points')

plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('Stasiun')
plt.ylabel('')  # Menghapus label sumbu y
plt.yticks([])  # Menghapus nilai-nilai pada sumbu y
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='Rata-rata', y='station', hue='Polusi', data=sorted_stations, palette='viridis')

# Menambahkan label pada setiap batang
for p in barplot.patches:
    width = p.get_width()    # get bar length
    barplot.text(width,       # set the text at 1 unit right of the bar
            p.get_y() + p.get_height() / 2, # get Y coordinate + X coordinate / 2
            '{:1.2f}'.format(width), # set variable to display, 2 decimals
            ha = 'left',   # horizontal alignment
            va = 'center')  # vertical alignment

plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('Rata-rata Tingkat Polusi')
plt.ylabel('Stasiun')  
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='Rata-rata', y='station', hue='Polusi', data=sorted_stations, palette='viridis')

# Menambahkan label pada setiap batang
for p in barplot.patches:
    width = p.get_width()    # get bar length
    barplot.text(width,       # set the text at 1 unit right of the bar
            p.get_y() + p.get_height() / 2, # get Y coordinate + X coordinate / 2
            '{:1.2f}'.format(width), # set variable to display, 2 decimals
            ha = 'left',   # horizontal alignment
            va = 'center')  # vertical alignment

plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('')  # Menghapus label sumbu x
plt.ylabel('')  # Menghapus label sumbu y
plt.xticks([])  # Menghapus nilai-nilai pada sumbu x
plt.yticks([])  # Menghapus nilai-nilai pada sumbu y
plt.legend().remove()  # Menghapus legenda
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='Rata-rata', y='station', hue='Polusi', data=sorted_stations, palette='viridis')

# Menambahkan label pada setiap batang
for p in barplot.patches:
    width = p.get_width()    # get bar length
    barplot.text(width,       # set the text at 1 unit right of the bar
            p.get_y() + p.get_height() / 2, # get Y coordinate + X coordinate / 2
            '{:1.2f}'.format(width), # set variable to display, 2 decimals
            ha = 'left',   # horizontal alignment
            va = 'center')  # vertical alignment

plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('')  # Menghapus label sumbu x
plt.ylabel('')  # Menghapus label sumbu y
plt.xticks([])  # Menghapus nilai-nilai pada sumbu x
plt.legend().remove()  # Menghapus legenda
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil data stasiun dan tingkat polusi dari dataframe
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Melt dataframe untuk mempermudah visualisasi
melted_pollution = pd.melt(average_pollution.reset_index(), id_vars='station', value_vars=['PM2.5', 'PM10'], var_name='Polusi', value_name='Rata-rata')

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = melted_pollution.sort_values(by='Rata-rata', ascending=False)

# Visualisasi Bar Chart grup untuk PM2.5 dan PM10
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='Rata-rata', y='station', hue='Polusi', data=sorted_stations, palette='viridis')

# Menambahkan label pada setiap batang
for p in barplot.patches:
    width = p.get_width()    # get bar length
    barplot.text(width,       # set the text at 1 unit right of the bar
            p.get_y() + p.get_height() / 2, # get Y coordinate + X coordinate / 2
            '{:1.2f}'.format(width), # set variable to display, 2 decimals
            ha = 'left',   # horizontal alignment
            va = 'center')  # vertical alignment

plt.title('Rata-rata Tingkat Polusi PM2.5 dan PM10 di Setiap Stasiun')
plt.xlabel('')  # Menghapus label sumbu x
plt.ylabel('')  # Menghapus label sumbu y
plt.xticks([])  # Menghapus nilai-nilai pada sumbu x
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
import seaborn as sns

# Ambil data tingkat polusi dan faktor cuaca
correlation_data = combined_df[['SO2', 'NO2', 'CO', 'TEMP', 'PRES', 'DEWP']]

# Hitung matriks korelasi
correlation_matrix = correlation_data.corr()

# Visualisasi heatmap matriks korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Matriks Korelasi antara Tingkat Polusi dan Faktor Cuaca')
plt.show()

# %%
# Ambil data stasiun dan tingkat polusi
station_pollution = combined_df[['station', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Sorting stasiun berdasarkan rata-rata PM2.5 (atau parameter lain yang Anda pilih)
sorted_stations = average_pollution.sort_values(by='PM2.5', ascending=False)

# Visualisasi Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x=sorted_stations.index, y=sorted_stations['PM2.5'], palette='viridis')
plt.title('Rata-rata Tingkat Polusi PM2.5 di Setiap Stasiun')
plt.xlabel('Stasiun')
plt.ylabel('Rata-rata Tingkat Polusi PM2.5')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_38252\2113284027.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sorted_stations.index, y=sorted_stations['PM2.5'], palette='viridis')

# %% [markdown]
# ### Pertanyaan 3:

# %%
import seaborn as sns

# Ambil data tingkat polusi dan faktor cuaca
pollution_weather_data = combined_df[['SO2', 'NO2', 'CO', 'TEMP', 'PRES', 'DEWP']]

# Buat matriks korelasi
correlation_matrix = pollution_weather_data.corr()

# Visualisasi matriks korelasi menggunakan heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Matriks Korelasi antara Tingkat Polusi dan Faktor Cuaca')
plt.show()

# %%
import seaborn as sns

# Ambil data O3
o3_data = combined_df[['year', 'O3']]

# Visualisasi box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='year', y='O3', data=o3_data)
plt.title('Distribusi Nilai O3 (Ozon) 2013-2017')
plt.xlabel('Tahun')
plt.ylabel('Nilai O3')
plt.show()

# %%
import seaborn as sns

# Ambil data stasiun dan tingkat polusi
station_pollution = combined_df[['station', 'PM2.5']]

# Hitung rata-rata tingkat polusi di setiap stasiun
average_pollution = station_pollution.groupby('station').mean()

# Sorting stasiun berdasarkan rata-rata PM2.5
sorted_stations = average_pollution.sort_values(by='PM2.5', ascending=False)

# Visualisasi Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x=sorted_stations.index, y=sorted_stations['PM2.5'], palette='viridis')
plt.title('Rata-rata Tingkat Polusi PM2.5 di Setiap Stasiun')
plt.xlabel('Stasiun')
plt.ylabel('Rata-rata Tingkat Polusi PM2.5')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_33608\955376223.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sorted_stations.index, y=sorted_stations['PM2.5'], palette='viridis')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - conclution pertanyaan 2
